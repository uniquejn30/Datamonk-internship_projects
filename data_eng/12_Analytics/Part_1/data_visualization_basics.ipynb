# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load built-in dataset
tips = sns.load_dataset("tips")

# Preview data
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(8, 5))
sns.histplot(tips["tip"], bins=20, kde=True)

plt.title("Distribution of Tip Amounts")
plt.xlabel("Tip Amount")
plt.ylabel("Frequency")

plt.show()

# %%
bill_by_time = tips.groupby("time")["total_bill"].mean().reset_index()
bill_by_time
# Out:
# /tmp/ipykernel_22031/3835864007.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bill_by_time = tips.groupby("time")["total_bill"].mean().reset_index()
#      time  total_bill
# 0   Lunch   17.168676
# 1  Dinner   20.797159

# %%
plt.figure(figsize=(6, 4))
sns.barplot(data=bill_by_time, x="time", y="total_bill")

plt.title("Average Total Bill by Time of Day")
plt.xlabel("Time")
plt.ylabel("Average Total Bill")

plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=tips, x="day", y="total_bill")

plt.title("Total Bill Distribution by Day")
plt.xlabel("Day")
plt.ylabel("Total Bill")

plt.show()

# %%
flights = sns.load_dataset("flights")

flights_pivot = flights.pivot(
    index="month",
    columns="year",
    values="passengers"
)

plt.figure(figsize=(10, 6))
sns.heatmap(
    flights_pivot,
    cmap="YlGnBu",
    linewidths=0.5
)

plt.title("Flight Passengers Heatmap")
plt.show()
